# %%
# %autosave 30
# Out:
# Autosaving every 30 seconds

# %%
cd ..
# Out:
# /home/huawei123/kwx1991442/code-classification

# %% [markdown]
# # baseline

# %%
import json
import os
import glob
from collections import namedtuple
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from typing import *

# %%
with open('config.json') as file:
    cfg = json.load(file)

# DATA_FOLDER = "data/rust/src/test/ui/"
DATA_FOLDER = cfg['DATA_FOLDER']
EXCLUDED_SUBDIRS = cfg['EXCLUDED_SUBDIRS']
CODEPARROT_FOLDER = cfg['CODEPARROT_FOLDER']

# %%
Item = namedtuple("Item", "fname relpath")
"""Structure to store location of each file

fname (str) : filename without extension (filename.*)
relpath (str) : relative path to the file (tests/ui/{relpath}/filename.*)
"""
# Out:
# 'Structure to store location of each file\n\nfname (str) : filename without extension (filename.*)\nrelpath (str) : relative path to the file (tests/ui/{relpath}/filename.*)\n'

# %%
import re
import tokenize
from io import BytesIO

class UITestsDataset(Dataset):
    data_folder: str
    mode: str
    items: List[Item]

    def __init__(self, tests_ui_folder: str = DATA_FOLDER, mode: str = 'train') -> None:
        super(UITestsDataset).__init__()
        self.data_folder = tests_ui_folder
        self.mode = mode
        self.items = self.get_items(tests_ui_folder, mode)

        self.compiled = re.compile(r'[A-Za-z_]+|-?\d+\.\d+|\d+|\W')
        # self.compiled = re.compile(r'[A-Za-z]+|-?\d+(?:\.\d+)?|(?:[^\w-]+|-(?!\d))+')


    def get_items(self, test_ui_folder: str, mode: str) -> List[Item]:
        items = []

        if mode == 'train':
            for path, _, files in os.walk(test_ui_folder):

                # Check that file is placed in a subdirectory
                if len(path) == len(test_ui_folder):
                    continue

                relpath = os.path.relpath(path, start=test_ui_folder)
                
                # Check that subdirectory should not be excluded
                if len(set(relpath.split(os.sep)) & set(EXCLUDED_SUBDIRS)) > 0:
                    continue

                for f in files:
                    fname, fext = os.path.splitext(f)

                    # Omit non .rs files
                    if fext != ".rs":
                        continue

                    new_item = Item(fname, relpath)
                    items.append(new_item)

        elif mode == 'infer':
            for path, _, files in os.walk(test_ui_folder):

                # Check that file is NOT placed in a subdirectory
                if len(path) != len(test_ui_folder):
                    continue

                for f in files:
                    fname, fext = os.path.splitext(f)

                    # Omit non .rs files
                    if fext != ".rs":
                        continue

                    new_item = Item(fname, '')
                    items.append(new_item)

                # Skip all other paths as they are in a subdirectories
                break
        else:
            return ValueError("Unknown `mode` passed to `get_items()` function. " 
            "Possible variants: `train` or `infer`. ")

        return items

    def item2text(self, item: Item) -> str:
        """Load and concatenate files for item
        
        {item.fname}.[rs,stderr,stdout]
        """
        search = os.path.join(self.data_folder, item.relpath, item.fname)
        extensions = ['.rs'] #, '.stderr', '.stdout']

        text = []
        for fname in [f for f in glob.glob(f"{search}*") \
            if os.path.splitext(f)[1] in extensions]:

            with open(fname, 'r') as file:
                text.append(file.read())
        
        return '\n\n'.join(text)

    def __len__(self):
        return len(self.items)

    def __getitem__(self, index: int) -> Tuple[np.ndarray, str]:
        item = self.items[index]
        text = self.item2text(item) #.split()
        label = item.relpath.split(os.sep)[0]
        return (text, label)

    @property
    def classes(self):
        return list(set([item.relpath.split(os.sep)[0] for item in self.items]))

    @property
    def vocab(self):
        vocab = set()
        for index in range(self.__len__()):
            words = self.__getitem__(index)[0]
            words = set(self.compiled.findall(words))
            # try:
            #     tokens = tokenize.tokenize(BytesIO(words.encode('utf-8')).readline)
            #     tokens = [token.string for token in tokens]
            vocab.update(words)
        return list(vocab)

# %%
t = UITestsDataset(DATA_FOLDER, 'train')

# %%
vocab = t.vocab

# %%
len(vocab)
# vocab[50:100]
# Out:
# 27702

# %%
vocab
# Out:
# ['VK',
#  'Unnamed',
#  'mem',
#  '198',
#  'cuviper',
#  'uninferred',
#  'Representing',
#  'run_fut',
#  'to_vector',
#  '1957',
#  'Heap',
#  'Luma',
#  '8624',
#  'ParallelIterator',
#  'FooX',
#  'borrow_local_inline_done',
#  'anon_const_non_local',
#  '2263',
#  'stable_in_unstable_std',
#  'OtherStream',
#  'is_es_identifier_start',
#  'TRAIT_MAGIC',
#  'clauses',
#  '0165',
#  '63151',
#  'semis',
#  'composition',
#  '01000',
#  'initializing',
#  'Three',
#  'assignment_to_field_projection',
#  'entry_a',
#  'ctpop',
#  'Read',
#  'SliceIndex',
#  '2521',
#  'TEST',
#  'rc_foo',
#  'Token',
#  '1730',
#  'implicit_ptr_trait',
#  'equals_self_wrapper',
#  '95327',
#  'const_intrinsic_copy',
#  'loaded',
#  'PolyGood',
#  '51',
#  'forall',
#  'test_op_assigns',
#  'right',
#  'impatient',
#  'ExampleOtherTuple',
#  'closable',
#  'no_relationships_late',
#  'HasMethod',
#  'assign',
#  'inherent_method_returning_unnameable_type',
#  '1078',
#  'bound_inv_a_b_vs_bound_inv_a',
#  'generality',
#  '1292',
#  'key_value_expansion',
#  'HOOK',
#  'almost_swapped',
#  'block_on',
#  'Using',
#  'tables',
#  'OT',
#  'des',
#  'ensure_object_safe',
#  'Foz',
#  'xABC_DEF_u',
#  'react',
#  '-3.0',
#  '0200',
#  'allocate',
#  'to_string',
#  '1260',
#  '0065',
#  'Quax',
#  'corrupt',
#  '830',
#  '38586',
#  'Literal',
#  'complicated_',
#  'Won',
#  'ascribe_field_ref',
#  'round',
#  'assert_copy',
#  'ThinBox',
#  '_mut_borrow',
#  '_mm_add_ps',
#  'check_display_eq',
#  'until',
#  'base_ptr',
#  'MyWeirdOption',
#  'Boo',
#  'DST',
#  'Slices',
#  'offsets',
#  'invalid_value',
#  'incoherent',
#  'no_least_region',
#  'LendingIterator',
#  'System',
#  'Mutability',
#  'ManyDefaultAttrs',
#  'J',
#  'tiny',
#  'AccessibleTraitAssoc',
#  '_also_moved',
#  'overwriting',
#  'derive_b_rpass',
#  'gen_inner_gen_invoc',
#  'generating',
#  'rhs_as_fixed',
#  'Converting',
#  'flaky',
#  '1099',
#  'saturating_and_wrapping',
#  'FooB',
#  'Eu',
#  'takes_future',
#  'peek',
#  'no_method_suggested_traits',
#  'here',
#  '52893',
#  'from_mono',
#  'impossible_to_call_c',
#  'merge_int_err',
#  'BarFoo',
#  'borrow_after_move',
#  '_bcx',
#  'current_provides',
#  'ྯ',
#  'simd_reduce_any',
#  'Lfoo',
#  'corridors_of_light',
#  'Condition',
#  '0102',
#  'contents',
#  'add_assign',
#  '1875',
#  'ness',
#  '006',
#  '_BDFF_DB',
#  '1000',
#  '31',
#  'VecDeque',
#  'MakeFooFn',
#  'Instability',
#  'IpuItertools',
#  'CBA',
#  '735',
#  'following',
#  'xFFFF_FFFF_FFFF_FFFF__FFFF_FFFF_FFFF_FFFF',
#  '32.0',
#  'no_new_warn',
#  'test_methods',
#  'FFF_FFFF_FFFF_FFFF',
#  'EAC',
#  '150',
#  'assert_hrtb',
#  'test_late_late',
#  'fadd_fast',
#  'Final',
#  'box_x_mut',
#  'core_intrinsics',
#  'rmeta_meta',
#  'map',
#  '53738',
#  '1109',
#  'broke',
#  '22.0',
#  'no_escape',
#  'BoxedDsl',
#  '0697',
#  '2128',
#  '3138',
#  'NaiveDate',
#  'possibility',
#  'my_float',
#  '1845',
#  '82518',
#  'make_g',
#  'LocalKind',
#  '0501',
#  'echo_tts',
#  'linearity',
#  'is_negative',
#  'lint_output_format',
#  'method_stable_text',
#  '256000',
#  '4200',
#  'unfortunately',
#  'LAYOUT_INVALID_THREE',
#  'FAIL',
#  'local_refutable',
#  'inventory',
#  '0020000020000001',
#  'non_borrow_type',
#  'unrsolved',
#  '_ACF',
#  'inference_unstable_iterator',
#  '310',
#  '100.0',
#  '888888888888888888888888888888888888888',
#  '436',
#  'enum_with_excessive_missing_variants',
#  'awaits',
#  'ModelT',
#  'either',
#  'Used',
#  '21397',
#  'SYLADEX',
#  'NumConv',
#  '1302',
#  '_data',
#  '0616',
#  'invalidating',
#  '821',
#  'improper_ctypes',
#  'enumeration',
#  'applies',
#  'STUDENT_HAPPINESS',
#  'Test',
#  'needs_evaluatable_bound_alias',
#  'ExternalIndirection',
#  'Unused',
#  'aa',
#  'clona',
#  'explicit_block',
#  'FI',
#  'opt_x',
#  'use_vararg_lifetime',
#  'compare_box',
#  '1152',
#  '♟',
#  'structural_impls',
#  '3119',
#  'BODY',
#  'several',
#  'inferring',
#  'test_generator',
#  'completeness',
#  '135',
#  '1337.0',
#  '0494',
#  '609',
#  'unused_macro',
#  'Mac',
#  'assert_two_copies',
#  'Filling',
#  '11000',
#  'as_chunks',
#  'Unevaluated',
#  '50072',
#  'classify',
#  '3033',
#  '2519',
#  'bytecode',
#  '0279',
#  '~',
#  'trip',
#  'a_f',
#  'BAD_UPVAR',
#  'macro_with_error',
#  '4287',
#  'fn_ptr_trait',
#  '62307',
#  'computing',
#  '99',
#  'child_filename',
#  'used_type_in_return',
#  'symmetric_difference',
#  'slated',
#  'wild_arr',
#  'instanciating',
#  'attempts',
#  'accept_fn_once',
#  'overly_complicated',
#  'stop',
#  'parenthesized',
#  'allsorts',
#  '0520',
#  'began',
#  'no_copy_no_debug',
#  'Aimpl',
#  'simulate',
#  'Sweet',
#  'insure',
#  '674',
#  'finds_explicit_bound',
#  'WRAP_DOUBLY_INDIRECT_PARAM',
#  'Invalid',
#  'realstd',
#  'assigned',
#  'autotrait',
#  'features',
#  'Dev',
#  '648',
#  'Allocated',
#  'shown',
#  '1084',
#  'arr_by_ref',
#  '87456',
#  '1691',
#  'FOREIGN_STATIC',
#  'priv',
#  '567',
#  '0361',
#  '_cell_b',
#  'u_size',
#  'AliasBurrito',
#  'underscore',
#  'for_extern',
#  'Hacky',
#  'cal',
#  'recently',
#  '60925',
#  'FCC',
#  'gimme_send',
#  'scalar',
#  'ln',
#  'non_shorthand_field_patterns',
#  'Collate',
#  'nhello',
#  'ReStatic',
#  '_savier',
#  'wild_tuple',
#  'Success',
#  '11669',
#  'QSelf',
#  'call_with_ref',
#  'async_wrong_without_args',
#  'set_short',
#  '1343',
#  'y_message',
#  'Adaptation',
#  'Implicit',
#  '-2147483649.0',
#  'ny',
#  'huh',
#  'trigger_bug',
#  'extern_fn_documented',
#  '1163',
#  'TheConst',
#  'user',
#  'grown',
#  'f',
#  'times',
#  'static_proc',
#  '80',
#  'can_parse_zero_as_f',
#  'wildly',
#  'Composite',
#  'aggressively',
#  '0352',
#  'influenced',
#  'punct',
#  'YIKES',
#  '69841',
#  '1306',
#  'NEG_OFLOW',
#  'improved',
#  'showed',
#  'call_unsafe_generic_cell_const_fn',
#  'triggered',
#  '0972',
#  'Cmp',
#  'move_part_await_return_rest_tuple',
#  'Out',
#  'writing',
#  'ConstGenericEnum',
#  'first_avail',
#  'Swap',
#  '3000',
#  'LocalInB',
#  'fences',
#  '00000000000000000000000',
#  '2399',
#  'remap',
#  'call_impl_trait_block',
#  'as_list',
#  'Binop',
#  '104240',
#  'improvement',
#  'import_crate_var',
#  'attribute_macro',
#  'Parameterized',
#  'DT',
#  '👀',
#  'EvaluatedToErr',
#  'TwoConsts',
#  'MiniYoke',
#  'Bar_',
#  'closure_hrtb',
#  'double_borrow',
#  '_run',
#  '1939',
#  'repr_simd',
#  '19791',
#  '683',
#  'my_u',
#  'my_attr',
#  'mpsc',
#  '179',
#  '072',
#  'confuse',
#  'conventional',
#  'DIR',
#  '1190',
#  'things',
#  'takes_fn_mut',
#  '0403',
#  'except',
#  'db',
#  'an_int',
#  'MutBoorrow',
#  '2479',
#  'More',
#  'cardinality',
#  'with_pub_restricted',
#  '93',
#  '1553',
#  'max_len_last',
#  'assign_noncopy_union_field',
#  'TeeOutlivesAyBeeYooWhereIsDebug',
#  '2310',
#  'ast_ty_to_ty',
#  '30.4',
#  'hsl',
#  '1446',
#  'beep',
#  '♸',
#  'SIMD',
#  '2340',
#  'probably',
#  'FiniteElement',
#  'reborrowed',
#  'public_module',
#  'OneFruit',
#  '54966',
#  'specified',
#  'arrives',
#  'normalizations',
#  '230',
#  'xstr',
#  'implications',
#  '695',
#  'closure_imm_capture_conflict',
#  'tempted',
#  'supply_cyclic_generator_return',
#  'closure_mut_capture_moved',
#  'thirteen',
#  'HACK',
#  'Choose',
#  'method_deprecated_unstable_text',
#  'show_hygiene',
#  'NON_NULL',
#  'mk_false',
#  '1184',
#  'Cycles',
#  'underconstrained',
#  'take_array_from_mut',
#  'LIST',
#  '47244',
#  'executable',
#  'PidChecking',
#  'traitimpl',
#  'DeadVariant',
#  '1.7976931348623159',
#  'Shows',
#  'second_ice',
#  '࿒',
#  'never_type_fallback',
#  'generate_dollar_ident',
#  'series',
#  '0282',
#  '2140',
#  'Guard',
#  'rejecting',
#  'layout_of',
#  'register_tool',
#  'zsts',
#  'CAD',
#  'actualty',
#  '54121',
#  'NonEmptyEnum',
#  'desuraged',
#  'replacing',
#  'and_then',
#  'require_pid',
#  'singleton_each',
#  'annot_reference_named_lifetime_in_closure',
#  '1231',
#  'targeted',
#  '-1.5',
#  'unused_assignments',
#  'ref',
#  'rethrow_targets_async_block_not_async_fn',
#  '0232',
#  '_out',
#  'fooo',
#  'bad_const_unsafe_deref_raw_underscore',
#  'SIG_DFL',
#  '88609',
#  'env_cmd',
#  'developers',
#  'but',
#  'break_ty',
#  'image',
#  'assert_impls_fn',
#  'Thumb',
#  '_no_space',
#  '6893',
#  'probing',
#  'ys',
#  'ity',
#  '1262',
#  'Ca',
#  'Mode',
#  'box_box_ref_Self',
#  'into_slice',
#  'Cmyk',
#  'bits',
#  'swap_regions',
#  'meh',
#  'Contains',
#  'another',
#  'ConstBytes',
#  'FnDefs',
#  'option_ref_ref',
#  '10',
#  '76740',
#  'observe',
#  'MyAllocator',
#  'test_ambiguous',
#  'parenthesize',
#  'opposed',
#  'vet',
#  '1127',
#  'Bottom',
#  't_or_f',
#  '1235',
#  'loop_count',
#  '_task_context',
#  '0320',
#  'semijoin',
#  'p_res',
#  'MatchArm',
#  '2040',
#  'Lockable',
#  '27579',
#  '435',
#  'leak',
#  'call_a_thunk',
#  'number_of_threads',
#  'exits',
#  'set_editor',
#  'libfoo',
#  '0033',
#  'borrow_from_arg_copy',
#  '44614',
#  'Coinductive',
#  'xxxx',
#  '☩',
#  'MAIN',
#  'pass_by_value',
#  'Verifies',
#  'Oops',
#  'bindings_after_at_or_patterns_borrows',
#  'hash',
#  '20296',
#  'IsTrue',
#  'dollar_crate_nested_encoding',
#  'asm_experimental_arch',
#  'char_type',
#  'TC',
#  'has_bound',
#  'RefStruct',
#  'large',
#  'control_flow_to_option',
#  'Inlining',
#  'add_str_to_float',
#  'used',
#  'intuitively',
#  '1378',
#  'DeprecatedType',
#  'Bort',
#  '47809',
#  'let_chain',
#  '_hair_space_around',
#  'number_of_tokens_in_a_prefixed_char_literal',
#  '1463',
#  'Placing',
#  '_local_partial_init_and_use_struct',
#  '82',
#  'crate_with_invalid_spans',
#  'yes_as_mut',
#  'XUnit',
#  'valbar_for_et_foo',
#  '81708',
#  'UnitUnion',
#  'SubStruct',
#  'is_directory',
#  'Arena',
#  'boxed_fn',
#  'HEX_DUMP',
#  'Signed',
#  'missing_docs',
#  'coercion',
#  '16749',
#  '♮',
#  'est',
#  'dedicated',
#  'should_reject_destructive_mutate_in_guard',
#  'require_copy',
#  'p_ref',
#  'Cllvm',
#  'statoclib',
#  '655',
#  '010.0',
#  'ACBDA',
#  'service_fn',
#  'Yoke',
#  'lt_in_fn',
#  'pointer',
#  'outer_field',
#  'from_ymd',
#  'NON_EXISTENT',
#  'rust_track_caller_ffi_test_tracked',
#  'intrinsic',
#  '855',
#  'addToInventory',
#  'DBE',
#  'not_found',
#  'deadcode',
#  'Until',
#  'CFG',
#  '609253',
#  'macros_cant_escape_mods',
#  'or_pat_arg',
#  'Boxed',
#  'same_types',
#  'FooHolder',
#  'reading',
#  '098',
#  'interfaces',
#  'linked_list',
#  'rc_i',
#  'direct',
#  'ImplIntoIter',
#  'A_CHAR_USIZE',
#  '527',
#  'local_rec',
#  'rc_AssocType',
#  '87803',
#  'FooOverwriteDefault',
#  'remote',
#  'CanBeNicheFilledButShouldnt',
#  'SIZE_OF_BAR',
#  'last',
#  '841',
#  'sha',
#  '133',
#  'stdlib',
#  'is_first',
#  'unsatisifable',
#  '638',
#  'semitransparent',
#  'unpark',
#  'Gal',
#  'newlines',
#  'BtNode',
#  '_argc',
#  'FuturesOrdered',
#  'tokeniser',
#  'ToNbt',
#  'fst',
#  'const_trait_impl',
#  'shadow_in_required',
#  '⚃',
#  'inline_bound_multi',
#  'compiled',
#  'chip_paint',
#  '9384',
#  '81943',
#  '1420',
#  '2207',
#  '☡',
#  '928',
#  'next_u',
#  'concrete_const',
#  'simple_yield_value',
#  'overflow_recurse',
#  'reminder',
#  'lint_reasons',
#  '39',
#  '78174',
#  '0660',
#  'Vehicle',
#  'value_iiiii',
#  'escape_debug',
#  'rec_',
#  'ྍ',
#  'snapshot',
#  '826',
#  '1974',
#  'SIGSEGV',
#  '671',
#  'goals',
#  'necessary',
#  'move_ptr_mut',
#  'roll',
#  'static_val',
#  'mk_reg',
#  'sneaky',
#  'near',
#  'peration',
#  '1.42',
#  'TeeWhereAyYooWhereIsDebugBee',
#  'this_compiles',
#  '1653',
#  'use_while_mut',
#  'ufcs_trait',
#  '_FFFF_FFFFu',
#  'other_ptr',
#  'compound',
#  '_call_pointer_fmt',
#  '30786',
#  'simd_cast_ptr',
#  'atomic_xadd_release',
#  'SingleUnused',
#  'ts_explicit',
#  'should_be_ok_with_nll',
#  'spurious',
#  'unconditional_panic',
#  'significance',
#  'env',
#  'DummyStruct',
#  'def',
#  '_Zero',
#  'repeated_capture',
#  'custom_flags',
#  'ctrl',
#  '419',
#  'arranges',
#  'extern_allowed',
#  'procmacro',
#  'consume_borrowed',
#  '068',
#  'Unpacked',
#  'About',
#  'struct_meta',
#  'wrong_index',
#  'regressed',
#  'Ccode',
#  '0701',
#  '536',
#  'peeled',
#  'descendant',
#  'ScopeChain',
#  '1158',
#  'Provoke',
#  'BitXor',
#  'r_s',
#  '0654',
#  'FooFamily',
#  '20885',
#  'block_overarching_alias_mut',
#  'abcde',
#  'Issue',
#  'typaram',
#  'mention',
#  'avoiding',
#  '105138',
#  'frameworks',
#  'Tokio',
#  '955',
#  '14660',
#  'UnstableUnitStruct',
#  '_fn',
#  'let_wild_gets_moved_expr',
#  'MyPtr',
#  '3165',
#  'PlusOne',
#  'Apple',
#  'Q',
#  'early',
#  'cake',
#  '̂',
#  '2474',
#  '0211',
#  'Fooer',
#  'foors_mod',
#  '68112',
#  'Theoretically',
#  'staticmeth',
#  'MaybeOwned',
#  'uintret',
#  '0681',
#  '_name',
#  '404',
#  'fortress',
#  '_write',
#  'ShrAssign',
#  'Covered',
#  'facet',
#  'grandparent_sibling_borrow',
#  'FooLike',
#  '46557',
#  'As',
#  'Pizza',
#  'process_exec',
#  '2186',
#  'real_tests',
#  '_quux',
#  'jazz',
#  '57571',
#  '226',
#  '3031',
#  '↦',
#  '410',
#  '1751',
#  'LIMIT',
#  'test_else_panic',
#  'librustc_feature',
#  'MalformedTy',
#  'inclusive_to',
#  'BCB',
#  '1693',
#  'TEST_STR',
#  'awaited',
#  'mmx_reg',
#  'STR_F',
#  '6000',
#  'summary',
#  'accum',
#  'TEST_DATA',
#  'move_then_borrow',
#  'nonlocal',
#  'PLACES',
#  '987654321.0',
#  'get_usize',
#  'unforgivingly',
#  '_quimby',
#  'computed',
#  'codepoint',
#  'possibly',
#  'proto',
#  'size_of_copy',
#  'is_zst',
#  'convoluted',
#  '55112',
#  'deprecated_mod',
#  '4567',
#  'with_macro_call_expr',
#  '1479',
#  'CommonPayloadField',
#  '1942',
#  'covered',
#  'maps',
#  'generic_function',
#  'doesnt_matter',
#  'this_should_fulfill_the_expectation',
#  'computer',
#  'bar_hrtb',
#  'pd',
#  'ERROR',
#  'Custom',
#  'doc_primitive',
#  'CONST_NON_TRIVIAL',
#  'unwinds',
#  'StateMachine',
#  'startfn',
#  'Anna',
#  'borrow_after_mut_borrow',
#  'add_direction',
#  'directive',
#  'varying',
#  'editions',
#  'captures',
#  'fixpoint',
#  '0508',
#  'current_width',
#  'dwBytes',
#  'apit_assoc_bound',
#  'test_early_late',
#  'Preamble',
#  'Mixed',
#  'half',
#  'vw',
#  'lint_on_top_level',
#  'ToString',
#  'UV',
#  'resolve',
#  'as_raw_fd',
#  'HasComponent',
#  'test_neq',
#  'manually_drop',
#  '54556',
#  'TwoTys',
#  '0550',
#  'range_to',
#  'what_if_we_use_panic_directly_in_stmt',
#  '214',
#  'cannot_partially_init_inner_adt_via_outer_with_drop',
#  'HandlerFamily',
#  '0720',
#  'new_foo',
#  'check_no_niche_opt',
#  'generated_foo',
#  '68295',
#  '0935',
#  'ConstUsize',
#  '617',
#  'Unless',
#  '1182',
#  'named_ref',
#  '1469',
#  'EARLY_DROP_C',
#  'Eat',
#  'uses_dollar_crate_legacy_nested',
#  'lint_unused_extern_crate',
#  'in_main',
#  'Found',
#  'curly__no_rhs_dollar__no_round',
#  'Answer',
#  'SomeOtherVariant',
#  '_h',
#  'rules',
#  'RequestParams',
#  'unrepresentable',
#  'Wait',
#  'UNALIGNED_BOX',
#  'ReprCu',
#  'trigger_unused_variables_macro',
#  'succeed',
#  'Tcx',
#  'macro_with_super_',
#  'dow_jan_',
#  'const_bool',
#  'has_clone',
#  'not_a_cfg',
#  '103705',
#  '89305',
#  '2325',
#  '1.844674407370955',
#  'direct_alias',
#  '1220',
#  '0023',
#  'UninhabitedStruct',
#  'deref_extend',
#  'Gat',
#  'print_target_and_args_consume',
#  'xFEDC_BA',
#  'on_structs_and_enums_xc',
#  'EDF',
#  'lpName',
#  'equal_regions_rev',
#  'replace',
#  '298',
#  'is_my_unsafe_trait',
#  'discrim',
#  'suffice',
#  '_',
#  'NULL_USIZE',
#  'BTS',
#  'print_ptr',
#  'sz',
#  'my_function',
#  'Transitive',
#  '_unused',
#  '3181',
#  'ambig',
#  'call_rec',
#  '890',
#  'lhs',
#  'REJECT',
#  '_FD',
#  'iterable',
#  'Deserializers',
#  'avr_interrupt',
#  'thread_local_extern_static',
#  'should_order_tag_and_fields_correctly',
#  'RefTrait',
#  'TestEnum',
#  'ARRAY',
#  'implementation',
#  'capacity',
#  '1979',
#  '0796',
#  'remotely',
#  'valid_subset',
#  'test_stack_assign',
#  'check_assoc_const',
#  'WRAP_NULL',
#  'unchecked_div',
#  'in_impl_Fn_return_in_parameters',
#  ...]

# %%
# Out:
# Эта строка написана DD.MM.YYYY, а могла бы и DD.MM.YYYY

# %%
import re
match = re.findall(r"([a-z]+)([0-9]+)|([0-9]+)([a-z]+)", 'foofo21rew2342sdf', re.I)
# if match:
#     items = match.groups()
# print(items)

# %%
match
# Out:
# [('foofo', '21', '', ''), ('rew', '2342', '', '')]

# %%
re.split(r"([a-z]+)([0-9]+)", 'fdsf423() _) 32dsf234')
# Out:
# ['', 'fdsf', '423', '() _) 32', 'dsf', '234', '']

# %%
# re.split(r"([a-z]+)([0-9]+)", s[:100])
print(re.split(r"([a-z]+)", ' '.join(s.split())))
# Out:
# ['#![', 'crate', '_', 'type', '="', 'lib', '"] #![', 'feature', '(', 'c', '_', 'variadic', ')] ', 'pub', ' ', 'unsafe', ' ', 'extern', ' "C" ', 'fn', ' ', 'use', '_', 'vararg', '_', 'lifetime', '( ', 'x', ': ', 'usize', ', ', 'y', ': ... ) -> &', 'usize', ' { //~ ERROR ', 'missing', ' ', 'lifetime', ' ', 'specifier', ' &0 } ', 'pub', ' ', 'unsafe', ' ', 'extern', ' "C" ', 'fn', ' ', 'use', '_', 'normal', '_', 'arg', '_', 'lifetime', '(', 'x', ': &', 'usize', ', ', 'y', ': ...) -> &', 'usize', ' { // OK ', 'x', ' } ', 'error', '[E0106]: ', 'missing', ' ', 'lifetime', ' ', 'specifier', ' --> $DIR/', 'variadic', '-', 'ffi', '-6.', 'rs', ':7:6 | LL | ) -> &', 'usize', ' { | ^ ', 'expected', ' ', 'named', ' ', 'lifetime', ' ', 'parameter', ' | = ', 'help', ': ', 'this', ' ', 'function', "'", 's', ' ', 'return', ' ', 'type', ' ', 'contains', ' ', 'a', ' ', 'borrowed', ' ', 'value', ', ', 'but', ' ', 'there', ' ', 'is', ' ', 'no', ' ', 'value', ' ', 'for', ' ', 'it', ' ', 'to', ' ', 'be', ' ', 'borrowed', ' ', 'from', ' ', 'help', ': ', 'consider', ' ', 'using', ' ', 'the', " `'", 'static', '` ', 'lifetime', " | LL | ) -> &'", 'static', ' ', 'usize', ' { | +++++++ ', 'error', ': ', 'aborting', ' ', 'due', ' ', 'to', ' ', 'previous', ' ', 'error', ' F', 'or', ' ', 'more', ' ', 'information', ' ', 'about', ' ', 'this', ' ', 'error', ', ', 'try', ' `', 'rustc', ' --', 'explain', ' E0106`.']

# %%
re.split(r"(\W+)", ' '.join(s.split()))
# Out:
# ['',
#  '#![',
#  'crate_type',
#  '="',
#  'lib',
#  '"] #![',
#  'feature',
#  '(',
#  'c_variadic',
#  ')] ',
#  'pub',
#  ' ',
#  'unsafe',
#  ' ',
#  'extern',
#  ' "',
#  'C',
#  '" ',
#  'fn',
#  ' ',
#  'use_vararg_lifetime',
#  '( ',
#  'x',
#  ': ',
#  'usize',
#  ', ',
#  'y',
#  ': ... ) -> &',
#  'usize',
#  ' { //~ ',
#  'ERROR',
#  ' ',
#  'missing',
#  ' ',
#  'lifetime',
#  ' ',
#  'specifier',
#  ' &',
#  '0',
#  ' } ',
#  'pub',
#  ' ',
#  'unsafe',
#  ' ',
#  'extern',
#  ' "',
#  'C',
#  '" ',
#  'fn',
#  ' ',
#  'use_normal_arg_lifetime',
#  '(',
#  'x',
#  ': &',
#  'usize',
#  ', ',
#  'y',
#  ': ...) -> &',
#  'usize',
#  ' { // ',
#  'OK',
#  ' ',
#  'x',
#  ' } ',
#  'error',
#  '[',
#  'E0106',
#  ']: ',
#  'missing',
#  ' ',
#  'lifetime',
#  ' ',
#  'specifier',
#  ' --> $',
#  'DIR',
#  '/',
#  'variadic',
#  '-',
#  'ffi',
#  '-',
#  '6',
#  '.',
#  'rs',
#  ':',
#  '7',
#  ':',
#  '6',
#  ' | ',
#  'LL',
#  ' | ) -> &',
#  'usize',
#  ' { | ^ ',
#  'expected',
#  ' ',
#  'named',
#  ' ',
#  'lifetime',
#  ' ',
#  'parameter',
#  ' | = ',
#  'help',
#  ': ',
#  'this',
#  ' ',
#  'function',
#  "'",
#  's',
#  ' ',
#  'return',
#  ' ',
#  'type',
#  ' ',
#  'contains',
#  ' ',
#  'a',
#  ' ',
#  'borrowed',
#  ' ',
#  'value',
#  ', ',
#  'but',
#  ' ',
#  'there',
#  ' ',
#  'is',
#  ' ',
#  'no',
#  ' ',
#  'value',
#  ' ',
#  'for',
#  ' ',
#  'it',
#  ' ',
#  'to',
#  ' ',
#  'be',
#  ' ',
#  'borrowed',
#  ' ',
#  'from',
#  ' ',
#  'help',
#  ': ',
#  'consider',
#  ' ',
#  'using',
#  ' ',
#  'the',
#  " `'",
#  'static',
#  '` ',
#  'lifetime',
#  ' | ',
#  'LL',
#  " | ) -> &'",
#  'static',
#  ' ',
#  'usize',
#  ' { | +++++++ ',
#  'error',
#  ': ',
#  'aborting',
#  ' ',
#  'due',
#  ' ',
#  'to',
#  ' ',
#  'previous',
#  ' ',
#  'error',
#  ' ',
#  'For',
#  ' ',
#  'more',
#  ' ',
#  'information',
#  ' ',
#  'about',
#  ' ',
#  'this',
#  ' ',
#  'error',
#  ', ',
#  'try',
#  ' `',
#  'rustc',
#  ' --',
#  'explain',
#  ' ',
#  'E0106',
#  '`.',
#  '']

# %%
s
# Out:
# '#![crate_type="lib"]\n#![feature(c_variadic)]\n\npub unsafe extern "C" fn use_vararg_lifetime(\n    x: usize,\n    y: ...\n) -> &usize { //~ ERROR missing lifetime specifier\n    &0\n}\n\npub unsafe extern "C" fn use_normal_arg_lifetime(x: &usize, y: ...) -> &usize { // OK\n    x\n}\n\n\nerror[E0106]: missing lifetime specifier\n  --> $DIR/variadic-ffi-6.rs:7:6\n   |\nLL | ) -> &usize {\n   |      ^ expected named lifetime parameter\n   |\n   = help: this function\'s return type contains a borrowed value, but there is no value for it to be borrowed from\nhelp: consider using the `\'static` lifetime\n   |\nLL | ) -> &\'static usize {\n   |       +++++++\n\nerror: aborting due to previous error\n\nFor more information about this error, try `rustc --explain E0106`.\n'

# %%
s="""// note that these aux-build directives must be in this order
// aux-build:svh-uta-base.rs
// aux-build:svh-utb.rs
// aux-build:svh-uta-change-use-trait.rs
// normalize-stderr-test: "(crate `(\w+)`:) .*" -> "$1 $$PATH_$2"

//! "svh-uta-trait.rs" is checking that we detect a
//! change from `use foo::TraitB` to use `foo::TraitB` in the hash

extern crate uta;
extern crate utb; //~ ERROR: found possibly newer version of crate `uta` which `utb` depends

fn main() {
    utb::foo()
}"""

# %%
from io import BytesIO
import tokenize


# with open('/home/huawei123/kwx1991442/code-classification/data/classifui/src/main.rs', 'rb') as f:
# tokens = tokenize.tokenize(f.readline)
tokens = tokenize.tokenize(BytesIO(s.encode('utf-8')).readline)
tokens = [token.string for token in tokens]
