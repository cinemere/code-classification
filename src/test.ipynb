# %%
# %autosave 30
# Out:
# Autosaving every 30 seconds

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /home/huawei123/kwx1991442/code-classification

# %%
from dataloader import UITestsDataset

# %%
train = UITestsDataset(mode='train')

# %%
s = train[1][1]
# Out:
# 2023-07-14 13:36:19.797098: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-14 13:36:20.444403: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tok = train.tokenizer

# %%
tok([s[:1500].split(),s[-2000:].split()])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tok([s[:1500].split(),s[-2000:].split()])
#
# File ~/kwx1991442/venv/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:2561, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2559     if not self._in_target_context_manager:
#    2560         self._switch_to_input_mode()
# -> 2561     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2562 if text_target is not None:
#    2563     self._switch_to_target_mode()
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

classes = train.classes
labelencoder = LabelEncoder().fit(classes)

# %%
# Out:
# array([267, 120, 104,  50, 179,  33,  62,  51, 254, 140,   2,  80, 184,
#         97, 292, 256, 211, 157, 151, 243, 250,  45,  32, 231, 146,  41,
#        205, 242,  88,  25, 272, 135,  13, 133,   0, 245, 119, 301, 154,
#        171,  37, 244, 246, 300, 106,  31, 280, 287, 199, 296, 193, 132,
#        107, 196, 226, 222, 159,  65,  83, 126, 268, 163, 198,  46,  54,
#        302,  47, 298, 270, 124, 175, 235, 305, 304,  52, 103, 230, 273,
#        241, 232, 185,  74, 234,  81,  49, 143,  29, 123,  15,  69, 223,
#         44, 165,  63, 255, 129, 213, 252, 265, 295, 190, 181, 111, 233,
#        130, 220,  67, 109,  60, 289, 168,  20, 269, 202, 153, 215, 142,
#         78,  16,  93,  27,  86,   6, 125, 209, 303, 275,  79,  70,  76,
#        160,  96,   7,  56,  92,  36, 116,  26,  84, 219, 290,  77,  99,
#         87, 173, 102, 170, 201, 195, 100,  40,  30, 251, 183, 227,  59,
#         39,  85, 274, 131, 279,  23, 186, 174,  71, 161,  94,  95, 122,
# ...

# %%
ls | wc -l
# Out:
# 5

# %%
# !ls /home/huawei123/kwx1991442/code-classification/data/rust/tests/ui/issues
# Out:
# auxiliary
# issue-100605.rs
# issue-100605.stderr
# issue-10228.rs
# issue-10291.rs
# issue-10291.stderr
# issue-102964.rs
# issue-102964.stderr
# issue-10396.rs
# issue-10412.rs
# issue-10412.stderr
# issue-10436.rs
# issue-10456.rs
# issue-10465.rs
# issue-10465.stderr
# issue-10545.rs
# issue-10545.stderr
# issue-10638.rs
# issue-10656.rs
# issue-10656.stderr
# issue-106755.rs
# issue-106755.stderr
# issue-10682.rs
# issue-10683.rs
# issue-10718.rs
# issue-10734.rs
# issue-10764.rs
# issue-10764.stderr
# issue-10767.rs
# issue-10802.rs
# issue-10806.rs
# issue-10853.rs
# issue-10877.rs
# issue-10877.stderr
# issue-10902.rs
# issue-11004.rs
# issue-11004.stderr
# issue-11047.rs
# issue-11085.rs
# issue-11192.rs
# issue-11192.stderr
# issue-11205.rs
# issue-11224.rs
# issue-11267.rs
# issue-11374.rs
# issue-11374.stderr
# issue-11382.rs
# issue-11384.rs
# issue-11508.rs
# issue-11515.rs
# issue-11515.stderr
# issue-11529.rs
# issue-11552.rs
# issue-11592.rs
# issue-11593.rs
# ...
